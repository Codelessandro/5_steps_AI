# %% [markdown]
# # **5 Steps to build your AI:**
# 1. Data loading and preprocessing
# 2. Build your model
# 3. Train
# 4. Test
# 5. Coffee break

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'''Hands On: Hello World'''

# %%
# !pip install tensorflow
# !pip install matplotlib

# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Data loading and Data preprocessing

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
plt.imshow(train_images[0])
plt.colorbar()

# %%
''' Hands On Task 2: Show one more images from test set '''

# %%
for c in train_images[1]:
  x_str = np.array_repr(c).replace('\n', '').replace('array([', '').replace('], dtype=uint8)', '').replace(',', '')
  print(x_str)

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # *2*. Build your model

# %% [markdown]
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Colored_neural_network.svg/280px-Colored_neural_network.svg.png)

# %%
''' Hands On Task: Build your own model. Use Deep Learning if you can!  '''

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # **3**. Train

# %%
hist = model.fit(train_images, train_labels, epochs=20, validation_split=0.2)

plt.plot(hist.history['loss'], c='green')
plt.plot(hist.history['val_loss'], c='blue')

plt.show()

# %%
''' Hands On Task: Interpret your plot! Can your model generalize and learn on new data?'''

# %% [markdown]
# # 4. Test

# %%
model.predict(test_images[[0]])

# %%
class_names[9]

# %%
''' Hands On: Say for one other than test_images[0] if the AI was able to say what type of clothes it is.

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)

# %% [markdown]
# # 5. Coffee Break

# %%
print("Finally some coffee!")
